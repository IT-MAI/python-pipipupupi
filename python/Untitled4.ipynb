# %%
# №1
a=int(input())
b=int(input())
c=int(input())
x1=(-b+((b*b-4*a*c)**0.5))/(2*a)
x2=(-b-((b*b-4*a*c)**0.5))/(2*a)
print(x1)
print(x2)

# №2
N=int(input())
i=1
while i**2<=N:
    print(i**2)
    i+=1

# №3
n = int(input())
i = 2
while n % i != 0:
    i += 1

# №4
n=int(input())
if n==0:
    print(0)
else:
    a, b = 0, 1
    for i in range(2, n+1):
        a, b=b, a+b

# №5
a=input()
for i in range(0, len(a), 2):
    print(a[i])

# №6
s=input()
for i in s:
    if int(i)%2 == 0:
       print(i, end=' ')

# №7
a = [int(i) for i in input().split]
for i in range(1, len(a)):
    if a[i - 1] * a[i] > 0:
        print(a[i - 1], a[i])
        break
    

# №9
a = [int(i) for i in input()]
b = 0
for i in range(1, len(a) - 1):
    if a[i - 1] < a[i] > a[i + 1]:
        b += 1
print(b)

# №10
a = [int(i) for i in input().split()]
x = int(input())
b = 0
while b < len(a) and a[b] >= x:
    b += 1
print(b + 1)

# №11
b=[int(i) for i in input().split()]
z=1
for i in range(0, len(b)-1):
    if b[i]!=b[i+1]:
        z+=1
    
# №12
inmax=0
c=[int(i) for i in input().split()]
for i in range(1, len(c)):
    if c[i]>c[inmax]:
        inmax=i
print(c[inmax])
print(inmax+1)

# №13
s = 0
c = 1
a = []
while c != 0:
    c = int(input())
    a.append(c)
m = max(a)
for i in range(len(a)):
    if a[i] == m:
        s += 1
print (s)

# №14
s = 0
c = 1
a = []
while c != 0:
    c = int(input())
    a.append(c)
for i in range(len(a)):
    if a[i] == a[i + 1]:
        s += 1
    else:
        if q < s:
            q = s
        s = 0
print(q)

# №16
d=[int(i) for i in input().split()]
r=[int(i) for i in input().split()]
f=d[0]*r[0]+d[1]*r[1]+d[2]*r[2]
print(f)
# Out:
# 2
# 4
# 5
# (-0.9999999999999999+1.224744871391589j)
# (-1-1.224744871391589j)
# 4
# 1
# 4
# 54
# 45
# 4
# 4
# Введите последовательность чисел через пробел
# 4
# Четные элементы данной последовательности:
# 4 Введите последовательность чисел через пробел
# 45
# Введите последовательность натуральных чисел, последний элемент которой равен 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f3c855a039ba> in <module>
#      57
#      58 print("Введите последовательность натуральных чисел, последний элемент которой равен 0")
# ---> 59 pre=int(input())
#      60 ans=0
#      61 while pre!=0:
#
# C:\Users\Public\1232\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\Users\Public\1232\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
2
