# %%
#1

print('введите числа через пробел')
a = [int(x) for x in input().split()]
b=set(a)
print(len(b))

#2

print('введите числа через пробел')
a= input().split()
a1 = input().split()
b=set(a)
b1=set(a1)
c=b1.intersection(b)
print(len(c))

#3


print('введите числа через пробел')
a=input().split()
a1 = input().split()
b=set(a)
b1=set(a1)
c=list(b1.intersection(b))
print(sorted(c))

#4

print('введите числа через пробел')
a = input().split()
c= set()
for i in a:
    if i in c:
        print('yes')
    else:
        print('no')
        c.add(i)
        
#5

number = int(input())
set1 = set()
for i in range(0, number):
    set1.update(str(s) for s in input().split())
print(len(set1))

#6

a = {}
c = input().split()
for i in c:
    a[i]=a.get(i,0)+1 
    print(a[i]-1)
    
#7
    
n = int(input())
d = {}
for i in range(n):
    first, second = input().split()
    d[first] = second
    d[second] = first
print(d[input()])    

#8

counter = {}
for i in range(int(input())):
    line = input().split()
    for word in line:
        counter[word] = counter.get(word, 0) + 1
         
max_count = max(counter.values())
most_f = [k for k, v in counter.items() if v == max_count]
print(min(most_f))
# Out:
# введите числа через пробел
# 1 2 3
# 3
# введите числа через пробел
# 2 3 1
#  1 4 2
# 2
# введите числа через пробел
# 1 2 3
# 2 3 4
# ['2', '3']
# введите числа через пробел
# 1 2 5 2 1
# no
# no
# no
# yes
# yes
