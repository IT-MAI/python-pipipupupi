# %%
#№1

n = int(input())
k = int(input())
print (k//n, k%n)

#№2

n = int(input())
ch = n//60
mn = n % 60
while ch > 23:
    ch -= 24
print (ch, ':',mn)

#№3

n = int(input())
if (n%4==0 and n%100!=0) or n%400==0:
    print('YES')
else:
    print ('NO')

#№4

a = int(input())
b = int(input())
c = int(input())
print(min(a, b, c))

#№5

sk1 = int(input())
sb1 = int(input())
sk2 = int(input())
sb2 = int(input())
if sk1%2==0 and sk2%2==0:
    if sb1%2 == sb2%2:
        print ('YES')
    else:
        print ('NO')
elif sk1%2!=0 and sk2%2==0:
    if sb1%2 != sb2%2:
        print ('YES')
    else:
        print ('NO')
elif sk1%2==0 and sk2%2!=0:
    if sb1%2 != sb2%2:
        print ('YES')
    else:
        print ('NO')
elif sk1%2!=0 and sk2%2!=0:
    if sb1%2 == sb2%2:
        print ('YES')
    else:
        print ('NO')
        
#6

line1 = int(input())
column1 = int(input())
line2 = int(input())
column2 = int(input())
if line1 == line2 or column1 == column2:
    print('YES')
else:
    print('NO')

#7

line1 = int(input())
column1 = int(input())
line2 = int(input())
column2 = int(input())
a = abs(line1 - line2)
b = abs(column1 - column2)
if a == 1 and b == 2 or a == 2 and b == 1:
    print('YES')
else:
    print('NO')
    
#8

N = int(input())
M = int(input())
x = int(input())
y = int(input())
if N > M:
    N,M=M,N
if x > N / 2:
    x = N - x
if y > M / 2:
    y = M - y
if x < y:
    print(x)
else:
    print(y)
